# %% [markdown]
# # view vs reshape — 验证 lab
#
# 对应叶子: `fundamentals/pytorch-tensor-lifecycle/view-vs-reshape`
#
# 本 notebook 用于**用代码检验理解**，不是复现教程。至少包含一个失败模式实验或一个数量级估算。

# %%
# 环境自检
import sys
print(sys.version)
try:
    import torch
    print('torch', torch.__version__, 'cuda', torch.cuda.is_available(), 'mps', torch.backends.mps.is_available())
except ImportError:
    print('torch 未安装')

# %% [markdown]
# ## 假设 (Hypothesis)
#
# 我预测：...

# %%
# 失败模式实验 / 数量级估算
# TODO: 写一段会触发预期现象的代码，观察是否与假设一致

# %% [markdown]
# ## 观察与解释
#
# - 观察（保留数字与单位）：
# - 解释：
# - **不能证明**：
